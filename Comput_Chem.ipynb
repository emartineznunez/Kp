# %%
# %pip install py3Dmol pubchempy chempy
# %pip install --prefer-binary pyscf
# %pip install pyscf[geomopt,dispersion]
# Out:
# Requirement already satisfied: py3Dmol in /usr/local/lib/python3.11/dist-packages (2.5.0)
# Collecting pubchempy
#   Downloading PubChemPy-1.0.4.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Collecting chempy
#   Downloading chempy-0.9.0.tar.gz (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.7/184.7 kB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>1.11.3 in /usr/local/lib/python3.11/dist-packages (from chempy) (1.26.4)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from chempy) (1.15.3)
# Requirement already satisfied: matplotlib>=2.2.3 in /usr/local/lib/python3.11/dist-packages (from chempy) (3.10.0)
# Requirement already satisfied: sympy!=1.2,>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from chempy) (1.13.1)
# Collecting quantities>=0.12.1 (from chempy)
#   Downloading quantities-0.16.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting pyneqsys>=0.5.5 (from chempy)
#   Downloading pyneqsys-0.5.7.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyodesys>=0.14.4 (from chempy)
#   Downloading pyodesys-0.14.4.tar.gz (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.9/107.9 kB 8.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from chempy) (3.2.3)
# Collecting sym>=0.3.4 (from chempy)
#   Downloading sym-0.3.5.tar.gz (31 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pulp>=1.6.8 (from chempy)
#   Downloading pulp-3.2.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting dot2tex>=2.11.3 (from chempy)
#   Downloading dot2tex-2.11.3-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.2.3->chempy) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.2.3->chempy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.2.3->chempy) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.2.3->chempy) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.2.3->chempy) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.2.3->chempy) (11.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.2.3->chempy) (2.9.0.post0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.11/dist-packages (from pyodesys>=0.14.4->chempy) (6.5.7)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy!=1.2,>=1.1.1->chempy) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=2.2.3->chempy) (1.17.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from notebook->pyodesys>=0.14.4->chempy) (3.1.6)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from notebook->pyodesys>=0.14.4->chempy) (6.4.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from notebook->pyodesys>=0.14.4->chempy) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook->pyodesys>=0.14.4->chempy) (25.1.0)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.11/dist-packages (from notebook->pyodesys>=0.14.4->chempy) (5.7.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.11/dist-packages (from notebook->pyodesys>=0.14.4->chempy) (5.8.1)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in /usr/local/lib/python3.11/dist-packages (from notebook->pyodesys>=0.14.4->chempy) (6.1.12)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.11/dist-packages (from notebook->pyodesys>=0.14.4->chempy) (0.2.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from notebook->pyodesys>=0.14.4->chempy) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook->pyodesys>=0.14.4->chempy) (7.16.6)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.11/dist-packages (from notebook->pyodesys>=0.14.4->chempy) (1.6.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.11/dist-packages (from notebook->pyodesys>=0.14.4->chempy) (6.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook->pyodesys>=0.14.4->chempy) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook->pyodesys>=0.14.4->chempy) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook->pyodesys>=0.14.4->chempy) (0.22.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook->pyodesys>=0.14.4->chempy) (1.3.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.1->notebook->pyodesys>=0.14.4->chempy) (4.3.8)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook->pyodesys>=0.14.4->chempy) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook->pyodesys>=0.14.4->chempy) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook->pyodesys>=0.14.4->chempy) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook->pyodesys>=0.14.4->chempy) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook->pyodesys>=0.14.4->chempy) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook->pyodesys>=0.14.4->chempy) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook->pyodesys>=0.14.4->chempy) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook->pyodesys>=0.14.4->chempy) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook->pyodesys>=0.14.4->chempy) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook->pyodesys>=0.14.4->chempy) (2.19.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook->pyodesys>=0.14.4->chempy) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook->pyodesys>=0.14.4->chempy) (4.24.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.11/dist-packages (from terminado>=0.8.3->notebook->pyodesys>=0.14.4->chempy) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook->pyodesys>=0.14.4->chempy) (21.2.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel->notebook->pyodesys>=0.14.4->chempy) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->notebook->pyodesys>=0.14.4->chempy) (7.34.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->notebook->pyodesys>=0.14.4->chempy) (0.1.7)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel->notebook->pyodesys>=0.14.4->chempy) (5.9.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook->pyodesys>=0.14.4->chempy) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook->pyodesys>=0.14.4->chempy) (1.4.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->notebook->pyodesys>=0.14.4->chempy) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->notebook->pyodesys>=0.14.4->chempy) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->notebook->pyodesys>=0.14.4->chempy) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->notebook->pyodesys>=0.14.4->chempy) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->notebook->pyodesys>=0.14.4->chempy) (3.0.51)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->notebook->pyodesys>=0.14.4->chempy) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->notebook->pyodesys>=0.14.4->chempy) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook->pyodesys>=0.14.4->chempy) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook->pyodesys>=0.14.4->chempy) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook->pyodesys>=0.14.4->chempy) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook->pyodesys>=0.14.4->chempy) (0.25.1)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->pyodesys>=0.14.4->chempy) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->pyodesys>=0.14.4->chempy) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook->pyodesys>=0.14.4->chempy) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook->pyodesys>=0.14.4->chempy) (4.14.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->pyodesys>=0.14.4->chempy) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook->pyodesys>=0.14.4->chempy) (0.8.4)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->pyodesys>=0.14.4->chempy) (4.9.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->pyodesys>=0.14.4->chempy) (1.8.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->notebook->pyodesys>=0.14.4->chempy) (0.2.13)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->pyodesys>=0.14.4->chempy) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->pyodesys>=0.14.4->chempy) (1.3.1)
# Downloading dot2tex-2.11.3-py2.py3-none-any.whl (36 kB)
# Downloading pulp-3.2.1-py3-none-any.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 99.7 MB/s eta 0:00:00
# Downloading quantities-0.16.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 8.0 MB/s eta 0:00:00
# Building wheels for collected packages: pubchempy, chempy, pyneqsys, pyodesys, sym
#   Building wheel for pubchempy (setup.py) ... done
#   Created wheel for pubchempy: filename=PubChemPy-1.0.4-py3-none-any.whl size=13818 sha256=628d4b52b952647d23aa4b5b459f1d76b0e4564ef50136bd00a4dfc801d5d747
#   Stored in directory: /root/.cache/pip/wheels/8b/e3/6c/3385b2db08b0985a87f5b117f98d0cb61a3ae3ca3bcbbd8307
#   Building wheel for chempy (setup.py) ... done
#   Created wheel for chempy: filename=chempy-0.9.0-py2.py3-none-any.whl size=210813 sha256=195ca5b38e5f5031853d415be18d9e9ca958f1f3bcc0a8f965bfaf14c6b85d62
#   Stored in directory: /root/.cache/pip/wheels/19/e6/e4/b4c7f8db20bfc94a706c4e51140aeeb8349f5be734b084ec12
#   Building wheel for pyneqsys (setup.py) ... done
#   Created wheel for pyneqsys: filename=pyneqsys-0.5.7-py2.py3-none-any.whl size=27266 sha256=2cbe67295f3601d80b04e758421742c52f2db3b660ffaf27fa814e5bf840c4f9
#   Stored in directory: /root/.cache/pip/wheels/6a/5e/15/bbf4cf359ef30f201b9ef84c8c5d65ec56014fe217ce3a38cc
#   Building wheel for pyodesys (setup.py) ... done
#   Created wheel for pyodesys: filename=pyodesys-0.14.4-py2.py3-none-any.whl size=122423 sha256=9de2674a5a5db8cc363c0d22087aa400d6f50bd53a3aa080a23129e71b094e98
#   Stored in directory: /root/.cache/pip/wheels/77/69/6a/483801fd8d98fbc79011d0564f26a2d4ec69a2119d60ae9f3f
#   Building wheel for sym (setup.py) ... done
#   Created wheel for sym: filename=sym-0.3.5-py2.py3-none-any.whl size=21077 sha256=1e3dc6694dafff464a8df23372b2e131f38198f03775705bb605d57986d4fd58
#   Stored in directory: /root/.cache/pip/wheels/a7/8d/f0/242b9fd69959ffa42353ccfcf95cf3ff2e21b0f32be7794047
# Successfully built pubchempy chempy pyneqsys pyodesys sym
# Installing collected packages: pubchempy, sym, quantities, pulp, dot2tex, pyneqsys, pyodesys, chempy
# Successfully installed chempy-0.9.0 dot2tex-2.11.3 pubchempy-1.0.4 pulp-3.2.1 pyneqsys-0.5.7 pyodesys-0.14.4 quantities-0.16.2 sym-0.3.5
# Requirement already satisfied: pyscf in /usr/local/lib/python3.11/dist-packages (2.9.0)
# Requirement already satisfied: numpy!=1.16,!=1.17,>=1.13 in /usr/local/lib/python3.11/dist-packages (from pyscf) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from pyscf) (1.15.3)
# Requirement already satisfied: h5py>=2.7 in /usr/local/lib/python3.11/dist-packages (from pyscf) (3.14.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from pyscf) (75.2.0)
# Requirement already satisfied: pyscf[dispersion,geomopt] in /usr/local/lib/python3.11/dist-packages (2.9.0)
# Requirement already satisfied: numpy!=1.16,!=1.17,>=1.13 in /usr/local/lib/python3.11/dist-packages (from pyscf[dispersion,geomopt]) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from pyscf[dispersion,geomopt]) (1.15.3)
# Requirement already satisfied: h5py>=2.7 in /usr/local/lib/python3.11/dist-packages (from pyscf[dispersion,geomopt]) (3.14.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from pyscf[dispersion,geomopt]) (75.2.0)
# Requirement already satisfied: pyberny>=0.6.2 in /usr/local/lib/python3.11/dist-packages (from pyscf[dispersion,geomopt]) (0.6.3)
# Requirement already satisfied: geometric>=0.9.7.2 in /usr/local/lib/python3.11/dist-packages (from pyscf[dispersion,geomopt]) (1.1)
# Requirement already satisfied: pyscf-qsdopt in /usr/local/lib/python3.11/dist-packages (from pyscf[dispersion,geomopt]) (0.1.0)
# Requirement already satisfied: pyscf-dispersion in /usr/local/lib/python3.11/dist-packages (from pyscf[dispersion,geomopt]) (1.3.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from geometric>=0.9.7.2->pyscf[dispersion,geomopt]) (3.5)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from geometric>=0.9.7.2->pyscf[dispersion,geomopt]) (1.17.0)

# %%
#@title Function to determine Gibbs free energy and entropy from statistical thermodynamics

# Defining some constants
m_u    = 1.66053886e-27      # atomic mass constant in kg
h      = 6.6260693e-34       # Planck's constant in J*s
k_B    = 1.3806505e-23       # Boltzmann's constant in J/K
c      = 2.99792558e8        # Speed of light in m/s
bar2Pa = 1e5                 # 1 bar to N/m**2
Pa2bar = 1e-5                # 1 Pa=N/m**2 to bar
p0     = 1                   # standard pressure in bar
R      = 8.31447e-3          # Gas constant in kJ/(K mol)
H2kcal = 627.509             # Hartree to kcal/mol
H2kJ   = 2625.5              # Hartree to kJ/mol
Rbar   = 0.0831447           # R in bar L / (mol K)
Rkcal  = 1.9872036e-3        # R in kcal mol-1 K-1


import numpy as np

def G_m_0(temp,m,A,B,C,lin_A,nat_A,sigma,spin,*freq):
  import math
  q_t = (2*math.pi*m*m_u*k_B*temp/h/h)**1.5*k_B*temp/bar2Pa
  q_r = 1 ; q_v = 1 ; Sr = 0 ; Sv = 0 ; Ur = 0 ; Uv = 0
  if nat_A > 1:
    rA  = h * c * 100 * A / k_B
    rB  = h * c * 100 * B / k_B
    rC  = h * c * 100 * C / k_B
    if lin_A == 0:
      q_r = 1 / sigma * math.sqrt(math.pi)*(temp**1.5/math.sqrt(rA*rB*rC))
    else:
      if rA == 0:
        rl = math.sqrt(rB*rC)
      elif rB == 0:
        rl = math.sqrt(rA*rC)
      else:
        rl = math.sqrt(rA*rB)
      q_r = 1 / sigma * temp / rl
    for ele in freq:
      rv   = h * c * 100 * float(ele) / k_B
      q_v *= 1 / (1 - np.exp(-rv/temp))
  q_e = spin + 1
  q = q_t * q_r * q_v * q_e
  return - R * temp * np.log(q)

def S_m_0(temp,m,A,B,C,lin_A,nat_A,sigma,spin,*freq):
  import math
  q_t = (2*math.pi*m*m_u*k_B*temp/h/h)**1.5*k_B*temp/bar2Pa
  St = R * (np.log(q_t) + 2.5)
  q_r = 1 ; q_v = 1 ; Sr = 0 ; Sv = 0
  if nat_A > 1:
    rA  = h * c * 100 * A / k_B
    rB  = h * c * 100 * B / k_B
    rC  = h * c * 100 * C / k_B
    if lin_A == 0:
      q_r = 1 / sigma * math.sqrt(math.pi)*(temp**1.5/math.sqrt(rA*rB*rC))
      Sr = R * (1.5 + np.log(q_r))
    else:
      if rA == 0:
        rl = math.sqrt(rB*rC)
      elif rB == 0:
        rl = math.sqrt(rA*rC)
      else:
        rl = math.sqrt(rA*rB)
      q_r = 1 / sigma * temp / rl
      Sr = R * (1 + np.log(q_r))
    for ele in freq:
      rv   = h * c * 100 * float(ele) / k_B
      q_v *= 1 / (1 - np.exp(-rv/temp))
      Sv  += R * (rv / temp / (np.exp(rv/temp) - 1) - np.log(1 - np.exp(-rv/temp)) )
  q_e = spin + 1
  S_e = R * np.log(q_e)
  S = St + Sr + Sv + S_e
  return S

# %%
#@title Using [Chempy](https://pypi.org/project/chempy/)

from operator import mul
from functools import reduce
from itertools import product
import chempy
from chempy import Substance
from chempy.chemistry import Species, Equilibrium, Reaction
from chempy.equilibria import EqSystem, NumSysLog, NumSysLin
from chempy import balance_stoichiometry
import numpy as np
import sympy as sp
sp.init_printing()
import matplotlib.pyplot as plt

temp = 298.15
reactf='N2O4'
prodf='NO2'
spin=[]
react = Substance.from_formula(reactf)
prod  = Substance.from_formula(prodf)
#print("Reactant:",react.unicode_name)
#print("Product :",prod.unicode_name)
spin_react=spin_prod=0
for ele in react.composition.keys(): spin_react += ele * react.composition[ele]
spin.append(spin_react % 2)
for ele in prod.composition.keys(): spin_prod += ele * prod.composition[ele]
spin.append(spin_prod % 2)
print("Spin list:",spin)

reac, pr = balance_stoichiometry({reactf},{prodf})

equilibrium = Equilibrium(reac, pr)

keys = [reactf,prodf]

subst = {k: Substance.from_formula(k) for k in keys}

r_latex=equilibrium.latex(subst)
r_unicode=equilibrium.unicode(subst)
print(r_unicode)
# Out:
# Spin list: [0, 1]
# N₂O₄ ⇌ 2 NO₂

# %%
#@title Retrieving structures of reactant and product from [PubChem](https://pubchem.ncbi.nlm.nih.gov/)
import pubchempy as pcp

keys1=['N2O4', 'nitrogen dioxide']
#print(keys)
#print(keys1)
natom = []
for k,ele in enumerate(keys1):
  molA = ele
  #molA = input('Name of your substance: ')
  queryA0 = pcp.get_compounds(molA,'name')
  queryA = pcp.get_compounds(molA,'name',record_type='3d')
  if(len(queryA)==0): queryA = queryA0
  cid_A = pcp.get_cids(molA)
  if len(cid_A) == 0: print('Molecule not found')
  else: print('CID of',Substance.from_formula(keys[k]).unicode_name,': ',cid_A)

  m = queryA[0]
  natom.append(len(m.atoms))
  f = open(keys[k]+'.xyz','w')
  if natom[k] > 1:
    f.write(str(natom[k])+'\n\n')
    for i,a in enumerate(m.atoms):
      if a.z is None: a.z = 0.0
      f.write(m.elements[i]+' '+str(a.x)+' '+str(a.y)+' '+str(a.z)+'\n')
  else:                            f.write(m.elements[0]+' 0. 0. 0.\n')
  f.close()
# Out:
# CID of N₂O₄ :  [25352]
# CID of NO₂ :  [3032552]

# %%
#@title ### Using [pyscf](https://pyscf.org) to optimize the structures at the PBE0-D4/6-31G level of theory. This takes a few minutes...
# %%capture
from pyscf import gto, scf
from pyscf.hessian import thermo
from pyscf.geomopt.geometric_solver import optimize

import os

#os.environ['OMP_NUM_THREADS'] = "8"

e0 = []
e0nd = []
zpe = []
lin = []
A = []
B = []
C = []
freq_info = []
mass = []
sigma = []
mol_eq = []
thermos = []

functional ='o3lyp-d4'
for k,ele in enumerate(keys):
  mol = gto.M(atom = ele+".xyz",spin=spin[k],basis='6-31g*')
  if spin[k] == 0: mf = mol.RKS(xc=functional)
  else: mf = mol.UKS(xc=functional)

  mf.grids.level = 5

# optimization
  mol_eq.append(optimize(mf, maxsteps=100))

  if spin[k] == 0: mf = mol_eq[k].RKS(xc=functional).run()
  else: mf = mol_eq[k].UKS(xc=functional).run()

  mf.grids.level = 5

  hessian = mf.Hessian().kernel()

  freq_info.append(thermo.harmonic_analysis(mf.mol, hessian))
  thermo_info = thermo.thermo(mf, freq_info[k]['freq_au'], temp, 101325)
  mass.append(mol.atom_mass_list(isotope_avg=True))
  rot_info = thermo.rotation_const(mass[k],mol_eq[k].atom_coords())
  sigma.append(thermo.rotational_symmetry_number(mol_eq[k]))

  A.append(rot_info[0] * 0.033357)
  B.append(rot_info[1] * 0.033357)
  C.append(rot_info[2] * 0.033357)
  if A[k] == B[k] and C[k] <= 0.001: lin.append(1)
  else: lin.append(0)

  e0.append(thermo_info['E0'][0])
  zpe.append(thermo_info['ZPE'][0])
  thermos.append(thermo_info)

# %%
#@title Computing DeltaG0 using the RRHO approximation and further approximations explained above (

#from x3dase.visualize import view_x3d_n
#from ase.io import read
#import IPython

gcorr = []
g = []
enthal = []
s = []

temp = 298.15
for k,ele in enumerate(keys):
  gcorr.append(G_m_0(temp,sum(mass[k]),A[k],B[k],C[k],lin[k],natom[k],sigma[k],spin[k],*freq_info[k]['freq_wavenumber']))
  g.append( (e0[k] + zpe[k]) * H2kJ + gcorr[k] )
  s.append(S_m_0(temp,sum(mass[k]),A[k],B[k],C[k],lin[k],natom[k],sigma[k],spin[k],*freq_info[k]['freq_wavenumber']))
  print('Frequencies of',Substance.from_formula(ele).unicode_name,'(cm^-1)')
  for ifreq in freq_info[k]['freq_wavenumber']:
    print('%10.0f' % ifreq)
  gto.tofile(mol_eq[k],str(keys[k])+'_opt.xyz')
  print("")


deltaG = (2 * g[1] - g[0])
deltaS = (2 * s[1] - s[0])
deltaH = deltaG  + temp * deltaS

print('deltaG: %8.5f kJ/mol' % deltaG)
print('deltaH: %8.5f kJ/mol' % deltaH)
print('deltaS: %8.5f kJ/mol' % deltaS)
# Out:
# Frequencies of N₂O₄ (cm^-1)
#         93
#        216
#        281
#        431
#        490
#        683
#        757
#        841
#       1346
#       1482
#       1868
#       1891
#
# Frequencies of NO₂ (cm^-1)
#        754
#       1415
#       1759
#
# deltaG:  5.38366 kJ/mol
# deltaH: 58.27809 kJ/mol
# deltaS:  0.17741 kJ/mol

# %%
import py3Dmol

view = py3Dmol.view(width=500, height=500)
view.addModel(open('N2O4_opt.xyz', 'r').read(), 'xyz')
view.setStyle({'stick':{'singleBonds' : 'False'},'sphere': {'scale': 0.3}})
view.show()
# Out:
# <div id="3dmolviewer_17503342944283986"  style="position: relative; width: 500px; height: 500px;">
#         <p id="3dmolwarning_17503342944283986" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.0/build/3Dmol-min.js');
# }
#
# var viewer_17503342944283986 = null;
# var warn = document.getElementById("3dmolwarning_17503342944283986");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17503342944283986 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17503342944283986"),{backgroundColor:"white"});
# viewer_17503342944283986.zoomTo();
# 	viewer_17503342944283986.addModel("6\nXYZ from PySCF\nO          -1.36284658        1.10199882        0.00005133\nO           1.36316469        1.10149809       -0.00005066\nO          -1.36280993       -1.10207970       -0.00006857\nO           1.36320632       -1.10148486        0.00006861\nN          -0.90409185       -0.00003055        0.00002825\nN           0.90327423       -0.00000188       -0.00002898\n","xyz");
# 	viewer_17503342944283986.setStyle({"stick": {"singleBonds": "False"}, "sphere": {"scale": 0.3}});
# viewer_17503342944283986.render();
# });
# </script>
